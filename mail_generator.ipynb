# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://internshala.com/internship/details/machine-learning-internship-in-multiple-locations-at-create-bytes1737116989")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
#
#
#
#
#
#
# Machine Learning Internship at Create Bytes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cancel
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cancel
# Yes
#
#
#
#
#
#
#
#
#
#
#
#
#         Oops, your browser does not support Javascript. Please use Internshala in another browser.
#
#
#
#
#
#             Loading, please wait...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         Student
#
#
#                                         Employer / T&P
#
#
#
#
#
#
#
#
#
#
#                                     Login with Google
#
#
#
#
#
# OR
#
#
#
#
#
#
# Email
#
#
#
# Password
#
#
#
# Forgot password?
#
#
# Login
#
#
#
#                                     New to Internshala? Register (Student / Company)
#
#
#
#
#
#
#
#
#
#
#
#
#                 Your account is put on hold.
#
#
#                 Your account is put on hold.
#
#
#
#
#                     What happened?
#
#
#                     We have determined that this account is violation of Internshala's rules.
#
#
#                     Specifically for,
#
#
#
#
#
#
#                     If you wish to appeal this, or seek further clarification, please contact our team at complaints@internshala.com
#
#
#
#
#
#                         If this has happened by mistake, it will automatically be reverted within 24 hours.
#
#
#
#
#
#
#
#
#
#
#
#
# Internships
#
#
# Jobs
#
#
#
#
#         Certification Courses
#
#
#
#
#
# Placement Guarantee Courses
#
#
#
#
# Contact Us
#
#
#
# Register - As a Student
#
#
# Register - As an Employer
#
#
# Login
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 Register
#
#
#
#
#
#
#
#
#
# Internships
#
#
#
#
#
#
#
#
#                                 Top Locations
#
#
#
#
#
#                                 Profile
#
#
#
#
#
#                                 Top Categories
#
#
#
#
#
#                                 Explore More Internships
#
#
#
#
#
#                                 Placement Guarantee Courses
#                                             NEW
#
#
#
#
#
#
#
# Work from Home
# Internship in Bangalore
# Internship in Delhi
# Internship in Hyderabad
# Internship in Mumbai
# Internship in Chennai
# Internship in Pune
# Internship in Kolkata
# Internship in Jaipur
# International Internship
# View all internships
#
#
#
#
# Computer Science Internship
# Marketing Internship
# Finance Internship
# Graphic Design Internship
# Architecture Internship
# Mechanical Internship
# HR Internship
# Digital Marketing Internship
# Law Internship
# Electronics Internship
# Content Writing Internship
# Civil Internship
# Campus Ambassador Program
# View all internships
#
#
#
#
# Engineering Internship
# Business/MBA Internship
# Part-Time Jobs/Internships
# Humanities Internship
# Science Internship
# Internships with Job Offer
# Internships for Women
# View all internships
#
#
#
#
# Internships by Category
# Internships by Location
#
#
#
#
# Full Stack Development Course
# Data Science Course
# Human Resource Management Course
# Digital Marketing Course
# Electric Vehicle Course
# UI/UX Design Course
# Product Management Course
# Financial Modelling Course
# Supply Chain Logistics Course
#
#
#
#
#
#
#
#
#         Courses
#
#
#
#
#
#
#                                 Certification Courses
#
#
#                                     Web Development
#
#                                     Programming with Python
#
#                                     Digital Marketing
#
#                                     Machine Learning
#
#                                     Advanced Excel
#
#                                     AutoCAD
#
#                                     Data Science
#
#                                     Programming with C and C++
#
#
#                                         View 70+ more courses
#
#
#
#
#
#
#                                 Placement Guarantee Courses
#
#
#                                     Full Stack Development Course
#
#                                     Data Science Course
#
#                                     Human Resource Management Course
#
#                                     Digital Marketing Course
#
#                                     Electric Vehicle Course
#
#                                     UI/UX Design Course
#
#                                     Product Management Course
#
#                                     Financial Modelling Course
#
#                                     Supply Chain Logistics Course
#
#
#
#
#
#
#
#
#
# Jobs
#
#
#
#
#
#
#
#
#                                 Top Locations
#
#
#
#
#
#                                 Top Categories
#
#
#
#
#
#                                 Explore More Jobs
#
#
#
#
#
#                                 Placement Guarantee Courses
#                                             NEW
#
#
#
#
#
#
#
# Work from home
# Jobs in Delhi
# Jobs in Mumbai
# Jobs in Bangalore
# Jobs in Hyderabad
# Jobs in Kolkata
# Jobs in Chennai
# Jobs in Pune
# Jobs in Jaipur
# View all jobs
#
#
#
#
# Fresher jobs
# Marketing jobs
# Content writing jobs
# Computer science jobs
# Finance jobs
# HR jobs
# Graphic design jobs
# Data science jobs
# View all jobs
#
#
#
#
# Jobs by Category
# Jobs by Location
# Jobs by Designation
# Jobs by Skill
#
#
#
#
# Full Stack Development Course
# Data Science Course
# Human Resource Management Course
# Digital Marketing Course
# Electric Vehicle Course
# UI/UX Design Course
# Product Management Course
# Financial Modelling Course
# Supply Chain Logistics Course
#
#
#
#
#
#
#
# Login / Register
#
#
#
#
#
#
# Register as a student
#
#
# Register as an employer
#
#
# Login
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 Reviewing your job posting
#
#
#                                 We’re reviewing your job details to ensure everything is in place.
#
#
#
#
#                                 Approving and posting your opportunity
#
#
#                                 Your opportunity is approved and live on our platform.
#
#
#
#
#                                 Searching for top candidates
#
#
#                                 We’re searching for top candidates matching your criteria.
#
#
#
#
#                                 Preparing a list of relevant candidates
#
#
#                                 We're curating a list of most relevant candidates for your post
#
#
#
#
#                                 Setting up your ATS
#
#
#                                 Setting up your Dashboard to manage incoming applications seamlessly
#
#
# This entire process takes about 2 minutes only
#
#
#
#
#
#
#
#
#
#
# One time offer
#
#
#
#
#
#
#
#
#
# Sign up now to unlock
#
#
#
# FREE AI Career Guide worth ₹599
#
#
#
# Custom job alerts delivered to your inbox
#
#
#
#                     Valid only for 05m : 00s
#
#
#
#                         By signing up, you agree to our Terms and Conditions.
#
#
#
#
#
#
#
#                                 Sign up with Google
#
#
#
#
# OR
#
#
#
# Sign up with Email
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Browse more internships
#
#
#     Machine Learning Internship
#
#
#
#
#
# Actively hiring
#
#
#
#
#                                 Machine Learning
#
#
#
#                                     Create Bytes
#
#
#
#
#
#
#
#
#
#
#
# Gurgaon, Jaipur
#
#
#
#
#
#
#
#                                     Start Date
#
#
# Starts immediatelyImmediately
#
#
#
#
# Duration
#
#
#                             3 Months
#
#
#
#
#
#
#
#                                 Stipend
#
#
# ₹ 10,000-30,000 /month
#
#
#
#
# APPLY BY
#
# 16 Feb' 25
#
#
#
#
#
#
#
#
# Posted 3 weeks ago
#
#
#
#
#
# Internship with job offer
#
#
#
#
#
#
#
#
#
#
#
# 1000+ applicants
#
#
#
#
#
#
#
#
# Share on WhatsApp
#
#
#
#
# Share on LinkedIn
#
#
#
#
# Share on Facebook
#
#
#
#
# Share on Twitter
#
#
#
#
# Copy link
#
#
#
#
#
#
#
#
# About the internship
#
#     As a Machine Learning intern at Create Bytes, you will have the unique opportunity to work with cutting-edge technology in the fields of Machine Learning, Python, Deep Learning, Data Science, Artificial Intelligence, Data Analytics, and Natural Language Processing (NLP). Your responsibilities will include:
#
# 1. Assisting in the development and implementation of machine learning algorithms for various projects.
# 2. Conducting data analysis and interpretation to optimize model performance.
# 3. Collaborating with the team to enhance existing machine learning models.
# 4. Researching and staying up-to-date on the latest advancements in the field of machine learning.
# 5. Supporting data cleaning and preprocessing tasks to ensure data quality.
# 6. Contributing to the design and implementation of AI solutions for real-world applications.
# 7. Presenting findings and recommendations to the team in a clear and concise manner.
#
# This is an exciting opportunity for a motivated individual to gain hands-on experience in machine learning and contribute to innovative projects at Create Bytes. Join us in shaping the future of AI technology!
# Send your applications at alaqsha.qadeer@createbytes.com
# Skill(s) required
#
# Artificial Intelligence
# Data Analytics
# Data Science
# Deep Learning
# Machine Learning
# Natural Language Processing (NLP)
# Python
#
#
# Earn certifications in these skills
#
#
# Learn Python
#
#
# Learn Voice App Development
#
#
# Learn Data Analytics
#
#
# Learn Machine Learning
#
#
# Learn Data Science
#
#
# Learn Deep Learning
#
#
#
# Who can apply
#
# Only those candidates can apply who:
#
#                         1. are available for full time (in-office) internship
#
#                         2. can start the internship between 17th Jan'25 and 21st Feb'25
#
#                         3. are available for duration of 3 months
#
#                         4. have relevant skills and interests
#
#
# Perks
#
# Certificate
#  Flexible work hours
#  Informal dress code
#  5 days a week
#  Job offer
#
# Number of openings
#
#         2
#
#                     About Create Bytes
#
# Website
#
#
#         We are a multifaceted studio that specializes in design, marketing, tech, product, and application development. Our team is made up of dedicated and hard-working individuals who are always inspired by your dreams and ideas. We believe in using our intellectual prowess to arrive at modernistic and user-friendly results, turning multiple bit-sized ideas into stunning bytes.
#
# Activity on Internshala
#
#
#
# Hiring since January 2020
#
#
#
# 58 opportunities posted
#
#
#
# 7 candidates hired
#
#
#
#
#
#
#
#                         Apply now
#
#
#
#
#
#
#
#
# Additional Questions
#
# ×
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
# Sign up to continue
#
#
#
#
#
#
#
#
#
#                     Sign up/ Login with Google
#
#
#
#
#
#
# OR
#
#
#
#
#
#
#
#
#
# Email
#
#
#
# Password
#
#
#
#
#
# First Name
#
#
#
#
#
# Last Name
#
#
#
#
#
#                 By signing up, you agree to our Terms and Conditions.
#
# Sign up
#
# Already registered?
#                             Login
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign up to continue
#
#
#
#
#
#
#
#
#
#                     Sign up/ Login with Google
#
#
#
#
#
#
# OR
#
#
#
#
#
#
#
#
#
# Email
#
#
#
# Password
#
#
#
#
#
# First Name
#
#
#
#
#
# Last Name
#
#
#
#
#
#                 By signing up, you agree to our Terms and Conditions.
#
# Sign up
#
# Already registered?
#                             Login
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Internships by places
#
# Internship in India
#
#
# Internship in Delhi
#
#
# Internship in Bangalore
#
#
# Internship in Hyderabad
#
#
# Internship in Mumbai
#
#
# Internship in Chennai
#
#
# Internship in Gurgaon
#
#
# Internship in Kolkata
#
#
# Virtual internship
#
#
# View all internships
#
#
#
#
#
# Internship by Stream
#
# Computer Science Internship
#
#
# Electronics Internship
#
#
# Mechanical Internship
#
#
# Civil Internship
#
#
# Marketing Internship
#
#
# Chemical Internship
#
#
# Finance Internship
#
#
# Summer Research Fellowship
#
#
# Campus Ambassador Program
#
#
# View all internships
#
#
#
#
#
# Jobs by Places
#
# Jobs in Delhi
#
#
# Jobs in Mumbai
#
#
# Jobs in Bangalore
#
#
# Jobs in Jaipur
#
#
# Jobs in Kolkata
#
#
# Jobs in Hyderabad
#
#
# Jobs in Pune
#
#
# Jobs in Chennai
#
#
# Jobs in Lucknow
#
#
# View all jobs
#
#
#
#
#
# Jobs by Stream
#
# Marketing jobs
#
#
# Content writing jobs
#
#
# Web development jobs
#
#
# Sales jobs
#
#
# Finance jobs
#
#
# Digital Marketing jobs
#
#
# Computer Science jobs
#
#
# Graphic Design jobs
#
#
# Data Science jobs
#
#
# View all jobs
#
#
#
#
#
#
#
# Placement Guarantee Courses
#
#
#
# Full Stack Development
#
#
# Data Science
#
#
# Human Resource Management
#
#
# Digital Marketing
#
#
# Electric Vehicle
#
#
# UI/UX Design
#
#
# Product Management
#
#
# Financial Modelling
#
#
# Supply Chain Logistics
#
#
#
# Certification Courses
#
#
#
#
#
#
#
#
#                                 Placement Guarantee Courses
#
#
#
#
# Full Stack Development
#
#
#
#
# Data Science
#
#
#
#
# Human Resource Management
#
#
#
#
# Digital Marketing
#
#
#
#
# Electric Vehicle
#
#
#
#
# UI/UX Design
#
#
#
#
# Product Management
#
#
#
#
# Financial Modelling
#
#
#
#
# Supply Chain Logistics
#
#
#
#
#
#                                 Certification Courses
#
#
#
#
#
# Jobs
#
# Jobs by Category
#
#
# Jobs by Location
#
#
# View all jobs
#
#
#
#
#
# About Internshala
#
#
#
# About us
#
#
# We're hiring
#
#
# Hire interns for your company
#
#
# Post a Job
#
#
# Team Diary
#
#
# Blog
#
#
# Our Services
#
#
# Free Job Alerts
#
#
#
#
# Terms & Conditions
#
#
# Privacy
#
#
# Contact us
#
#
# Sitemap
#
#
# College TPO registration
#
#
# List of Companies
#
#
#
#
#
#
#
#
#
#
# Jobs by Places
#
# Jobs in Delhi
#
#
# Jobs in Mumbai
#
#
# Jobs in Bangalore
#
#
# Jobs in Jaipur
#
#
# Jobs in Kolkata
#
#
# Jobs in Hyderabad
#
#
# Jobs in Pune
#
#
# Jobs in Chennai
#
#
# Jobs in Lucknow
#
#
# View all jobs
#
#
#
#
#
# Jobs by Stream
#
# Marketing jobs
#
#
# Content writing jobs
#
#
# Web development jobs
#
#
# Sales jobs
#
#
# Finance jobs
#
#
# Digital Marketing jobs
#
#
# Computer Science jobs
#
#
# Graphic Design jobs
#
#
# Data Science jobs
#
#
# View all jobs
#
#
#
#
#
# About Internshala
#
#
#
# About us
#
#
# We're hiring
#
#
# Hire interns for your company
#
#
# Post a Job
#
#
# Team Diary
#
#
# Blog
#
#
# Our Services
#
#
# Free Job Alerts
#
#
#
#
# Terms & Conditions
#
#
# Privacy
#
#
# Contact us
#
#
# Sitemap
#
#
#
#
#
#
#
#
#
#
#
#
#
# About us
#
#
# We're hiring
#
#
# Hire interns for your company
#
#
# Post a Job
#
#
#
#
#
#
# Team Diary
#
#
# Blog
#
#
# Our Services
#
#
# Free Job Alerts
#
#
#
#
#
#
# Terms & Conditions
#
#
# Privacy
#
#
# Contact us
#
#
#
#
#
#
# Sitemap
#
#
# College TPO registration
#
#
# List of Companies
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     © Copyright 2025 Internshala (Scholiverse Educare Private Limited)
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#
# Internships
#
#
#
#
#
# Jobs
#
#
#
#
#
#
# Courses

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
      """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)
chainextract = prompt_extract | llm
res = chainextract.invoke(input = {'page_data':page_data})
print(res.content)
# Out:
# ```json
# {
#   "role": "Machine Learning Intern",
#   "experience": "Internship",
#   "skills": [
#     "Artificial Intelligence",
#     "Data Analytics",
#     "Data Science",
#     "Deep Learning",
#     "Machine Learning",
#     "Natural Language Processing (NLP)",
#     "Python"
#   ],
#   "description": "As a Machine Learning intern at Create Bytes, you will have the unique opportunity to work with cutting-edge technology in the fields of Machine Learning, Python, Deep Learning, Data Science, Artificial Intelligence, Data Analytics, and Natural Language Processing (NLP). Your responsibilities will include: Assisting in the development and implementation of machine learning algorithms for various projects, Conducting data analysis and interpretation to optimize model performance, Collaborating with the team to enhance existing machine learning models, Researching and staying up-to-date on the latest advancements in the field of machine learning, Supporting data cleaning and preprocessing tasks to ensure data quality, Contributing to the design and implementation of AI solutions for real-world applications, Presenting findings and recommendations to the team in a clear and concise manner."
# }
# ```

# %%
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser
json_parser = JsonOutputParser()

# %%
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Machine Learning Intern',
#  'experience': 'Internship',
#  'skills': ['Artificial Intelligence',
#   'Data Analytics',
#   'Data Science',
#   'Deep Learning',
#   'Machine Learning',
#   'Natural Language Processing (NLP)',
#   'Python'],
#  'description': 'As a Machine Learning intern at Create Bytes, you will have the unique opportunity to work with cutting-edge technology in the fields of Machine Learning, Python, Deep Learning, Data Science, Artificial Intelligence, Data Analytics, and Natural Language Processing (NLP). Your responsibilities will include: Assisting in the development and implementation of machine learning algorithms for various projects, Conducting data analysis and interpretation to optimize model performance, Collaborating with the team to enhance existing machine learning models, Researching and staying up-to-date on the latest advancements in the field of machine learning, Supporting data cleaning and preprocessing tasks to ensure data quality, Contributing to the design and implementation of AI solutions for real-world applications, Presenting findings and recommendations to the team in a clear and concise manner.'}

# %%
type(json_res)
# Out:
# dict
